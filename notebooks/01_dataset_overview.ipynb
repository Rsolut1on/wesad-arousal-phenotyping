# %% [markdown]
# # 01 — WESAD Dataset Overview
#
# Exploratory notebook for subject counts, label distribution, and sampling rates.
# Run preprocessing first: `python scripts/run_preprocess.py`

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('..') / 'src'))

from wesad_arousal.config import load_config
from wesad_arousal.data import discover_subjects

cfg = load_config('../configs/default.yaml')
subjects = discover_subjects(Path(cfg['paths']['raw_dir']))
print(f'Subjects found: {len(subjects)}')
print(subjects)
